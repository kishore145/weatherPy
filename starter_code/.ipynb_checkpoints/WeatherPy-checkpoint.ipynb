# %% [markdown]
# !WeatherPy - Analysis
#
# Max temperature is higher near equator (-20 t0 + 40 degree latitude) at this time of year
# Southern hemisphere is more cooler this time of the year
# In most of the cities, the windspeed is between 0 - 10 mph
# Humidity doens't seem to have any correlation with Latitude
# Sky is mostly clear this time of the year and doesn't seem to have any correlation with Latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os, datetime

# Dependencies in case you want to use openwathermapy api wrapper
#import openweathermapy.core as owm

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countrycode =[]

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)


# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
        
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countrycode.append(country)
        
# Print the city count to confirm sufficient count
len(cities)
plt.scatter(lats,lngs)

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

#sample url and query to get the json details to find the variables we need for success response
response = requests.get('http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + api_key +'&q=Paris').json()
print(response)
unix_timestam = response['dt']

print(datetime.datetime.fromtimestamp(unix_timestam).strftime("%B %d, %Y"))

#sample url and query to get the json details to find the variables we need for failure response
response = requests.get('http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + api_key +'&q=Kishore').json()
print(response)
# Out:
# {'visibility': 10000, 'id': 2988507, 'cod': 200, 'name': 'Paris', 'coord': {'lat': 48.86, 'lon': 2.35}, 'dt': 1532412000, 'sys': {'id': 5617, 'sunrise': 1532405621, 'country': 'FR', 'sunset': 1532461186, 'type': 1, 'message': 0.0042}, 'weather': [{'description': 'clear sky', 'main': 'Clear', 'icon': '01d', 'id': 800}], 'wind': {'deg': 40, 'speed': 3.36}, 'base': 'stations', 'main': {'pressure': 1015, 'humidity': 60, 'temp': 69.19, 'temp_max': 71.6, 'temp_min': 66.2}, 'clouds': {'all': 0}}
# July 23, 2018
# {'cod': '404', 'message': 'city not found'}

# %%
# set up lists to hold reponse info

lat = []
lon = []
temp = []
humidity = []
cloudiness=[]
windspeed=[]
foundcity =[]
foundcityID = []
dt =[]
cc = []

baseurl = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + api_key +'&q='
recordcount = 0

# Header for log file
print("------------------------------")
print("Begin Data Retreival")
print("------------------------------")

# Loop through the list of cities and perform a request for data on each. Display message if city is not found. 
for city in cities:
    response = requests.get(baseurl + city).json()
    recordcount += 1
    print("Processing Record: " + str(recordcount) + " | " + city)
    print(baseurl + city)
    if(response['cod'] == 200):
        print("api call successful")
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        windspeed.append(response['wind']['speed'])
        cloudiness.append(response['clouds']['all'])
        foundcity.append(city)
        foundcityID.append(response['id'])
        cc.append(response['sys']['country'])
        dt.append(datetime.datetime.fromtimestamp(response['dt']).strftime("%B %d, %Y"))
        
    else:
        print("api call failed")
        print("Response code: " + str(response['cod']) + " Response Message: " + response['message'])
        
date = datetime.datetime.fromtimestamp(response['dt']).strftime("%B %d, %Y")
# Trailer for Log file
print("-------------------------------")
print("End Data Retreival")
print("-------------------------------")
# Out:
# ------------------------------
# Begin Data Retreival
# ------------------------------
# Processing Record: 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=vaini
# api call successful
# Processing Record: 2 | vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=vila
# api call successful
# Processing Record: 3 | ayios kirikos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ayios kirikos
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 4 | tabas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=tabas
# api call successful
# Processing Record: 5 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=kapaa
# api call successful
# Processing Record: 6 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=punta arenas
# api call successful
# Processing Record: 7 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=vestmannaeyjar
# api call successful
# Processing Record: 8 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=chokurdakh
# api call successful
# Processing Record: 9 | perry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=perry
# api call successful
# Processing Record: 10 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=beringovskiy
# api call successful
# Processing Record: 11 | healdsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=healdsburg
# api call successful
# Processing Record: 12 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=port blair
# api call successful
# Processing Record: 13 | barbastro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=barbastro
# api call successful
# Processing Record: 14 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=port alfred
# api call successful
# Processing Record: 15 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=qaanaaq
# api call successful
# Processing Record: 16 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=hobart
# api call successful
# Processing Record: 17 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=grand river south east
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 18 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=clyde river
# api call successful
# Processing Record: 19 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=sentyabrskiy
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 20 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=busselton
# api call successful
# Processing Record: 21 | keuruu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=keuruu
# api call successful
# Processing Record: 22 | wajima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=wajima
# api call successful
# Processing Record: 23 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=tsihombe
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 24 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=mataura
# api call successful
# Processing Record: 25 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=barentsburg
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 26 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=lavrentiya
# api call successful
# Processing Record: 27 | lillooet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=lillooet
# api call successful
# Processing Record: 28 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=iqaluit
# api call successful
# Processing Record: 29 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=avarua
# api call successful
# Processing Record: 30 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=pangnirtung
# api call successful
# Processing Record: 31 | anahuac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=anahuac
# api call successful
# Processing Record: 32 | houma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=houma
# api call successful
# Processing Record: 33 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=fortuna
# api call successful
# Processing Record: 34 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=bengkulu
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 35 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=castro
# api call successful
# Processing Record: 36 | bulancak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=bulancak
# api call successful
# Processing Record: 37 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=illoqqortoormiut
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 38 | sao paulo de olivenca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=sao paulo de olivenca
# api call successful
# Processing Record: 39 | pinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=pinsk
# api call successful
# Processing Record: 40 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=hilo
# api call successful
# Processing Record: 41 | gornopravdinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=gornopravdinsk
# api call successful
# Processing Record: 42 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=upernavik
# api call successful
# Processing Record: 43 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=nelson bay
# api call successful
# Processing Record: 44 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=puerto ayora
# api call successful
# Processing Record: 45 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=olafsvik
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 46 | tres arroyos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=tres arroyos
# api call successful
# Processing Record: 47 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=lorengau
# api call successful
# Processing Record: 48 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ushuaia
# api call successful
# Processing Record: 49 | matay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=matay
# api call successful
# Processing Record: 50 | xichang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=xichang
# api call successful
# Processing Record: 51 | anloga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=anloga
# api call successful
# Processing Record: 52 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=dikson
# api call successful
# Processing Record: 53 | zhitikara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=zhitikara
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 54 | prosvet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=prosvet
# api call successful
# Processing Record: 55 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=camacha
# api call successful
# Processing Record: 56 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=cherskiy
# api call successful
# Processing Record: 57 | krasnoturansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=krasnoturansk
# api call successful
# Processing Record: 58 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=albany
# api call successful
# Processing Record: 59 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=college
# api call successful
# Processing Record: 60 | snezhnogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=snezhnogorsk
# api call successful
# Processing Record: 61 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ribeira grande
# api call successful
# Processing Record: 62 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=leningradskiy
# api call successful
# Processing Record: 63 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=pevek
# api call successful
# Processing Record: 64 | nossa senhora da gloria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=nossa senhora da gloria
# api call successful
# Processing Record: 65 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=berlevag
# api call successful
# Processing Record: 66 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=bredasdorp
# api call successful
# Processing Record: 67 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=saint-pierre
# api call successful
# Processing Record: 68 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=carnarvon
# api call successful
# Processing Record: 69 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ilulissat
# api call successful
# Processing Record: 70 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=hasaki
# api call successful
# Processing Record: 71 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=atuona
# api call successful
# Processing Record: 72 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=cape town
# api call successful
# Processing Record: 73 | formosa do rio preto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=formosa do rio preto
# api call successful
# Processing Record: 74 | mitu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=mitu
# api call successful
# Processing Record: 75 | ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ballina
# api call successful
# Processing Record: 76 | sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=sibolga
# api call successful
# Processing Record: 77 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=isangel
# api call successful
# Processing Record: 78 | te horo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=te horo
# api call successful
# Processing Record: 79 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=saskylakh
# api call successful
# Processing Record: 80 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=butaritari
# api call successful
# Processing Record: 81 | verona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=verona
# api call successful
# Processing Record: 82 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=georgetown
# api call successful
# Processing Record: 83 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=vila franca do campo
# api call successful
# Processing Record: 84 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=taolanaro
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 85 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=aklavik
# api call successful
# Processing Record: 86 | olga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=olga
# api call successful
# Processing Record: 87 | sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=sangar
# api call successful
# Processing Record: 88 | baiyin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=baiyin
# api call successful
# Processing Record: 89 | okato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=okato
# api call successful
# Processing Record: 90 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=mys shmidta
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 91 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=husavik
# api call successful
# Processing Record: 92 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=hami
# api call successful
# Processing Record: 93 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=caravelas
# api call successful
# Processing Record: 94 | kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=kaeo
# api call successful
# Processing Record: 95 | ariquemes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ariquemes
# api call successful
# Processing Record: 96 | valparaiso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=valparaiso
# api call successful
# Processing Record: 97 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=palabuhanratu
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 98 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=hithadhoo
# api call successful
# Processing Record: 99 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=hermanus
# api call successful
# Processing Record: 100 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=hambantota
# api call successful
# Processing Record: 101 | amposta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=amposta
# api call successful
# Processing Record: 102 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=khatanga
# api call successful
# Processing Record: 103 | san bartolome de tirajana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=san bartolome de tirajana
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 104 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=sao joao da barra
# api call successful
# Processing Record: 105 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=nikolskoye
# api call successful
# Processing Record: 106 | kysyl-syr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=kysyl-syr
# api call successful
# Processing Record: 107 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=bambous virieux
# api call successful
# Processing Record: 108 | ulaanbaatar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ulaanbaatar
# api call successful
# Processing Record: 109 | fasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=fasa
# api call successful
# Processing Record: 110 | mendeleyevsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=mendeleyevsk
# api call successful
# Processing Record: 111 | kimbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=kimbe
# api call successful
# Processing Record: 112 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=klaksvik
# api call successful
# Processing Record: 113 | gari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=gari
# api call successful
# Processing Record: 114 | wahran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=wahran
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 115 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=geraldton
# api call successful
# Processing Record: 116 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=saint-philippe
# api call successful
# Processing Record: 117 | saint-gilles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=saint-gilles
# api call successful
# Processing Record: 118 | luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=luanda
# api call successful
# Processing Record: 119 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=talnakh
# api call successful
# Processing Record: 120 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=vao
# api call successful
# Processing Record: 121 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=mahebourg
# api call successful
# Processing Record: 122 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=lazaro cardenas
# api call successful
# Processing Record: 123 | karkaralinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=karkaralinsk
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 124 | san matias
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=san matias
# api call successful
# Processing Record: 125 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=tura
# api call successful
# Processing Record: 126 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=rikitea
# api call successful
# Processing Record: 127 | olen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=olen
# api call successful
# Processing Record: 128 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=bluff
# api call successful
# Processing Record: 129 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=cockburn town
# api call successful
# Processing Record: 130 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ostrovnoy
# api call successful
# Processing Record: 131 | ossora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ossora
# api call successful
# Processing Record: 132 | manado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=manado
# api call successful
# Processing Record: 133 | boueni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=boueni
# api call successful
# Processing Record: 134 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=saint-francois
# api call successful
# Processing Record: 135 | maracas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=maracas
# api call successful
# Processing Record: 136 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=san patricio
# api call successful
# Processing Record: 137 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=tuatapere
# api call successful
# Processing Record: 138 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=la ronge
# api call successful
# Processing Record: 139 | noshiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=noshiro
# api call successful
# Processing Record: 140 | bull savanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=bull savanna
# api call successful
# Processing Record: 141 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=faanui
# api call successful
# Processing Record: 142 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=avera
# api call successful
# Processing Record: 143 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=cidreira
# api call successful
# Processing Record: 144 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=lebu
# api call successful
# Processing Record: 145 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=grand gaube
# api call successful
# Processing Record: 146 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=jamestown
# api call successful
# Processing Record: 147 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=mar del plata
# api call successful
# Processing Record: 148 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=kaitangata
# api call successful
# Processing Record: 149 | marinhas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=marinhas
# api call successful
# Processing Record: 150 | pokhara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=pokhara
# api call successful
# Processing Record: 151 | brandfort
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=brandfort
# api call successful
# Processing Record: 152 | lingao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=lingao
# api call successful
# Processing Record: 153 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=yellowknife
# api call successful
# Processing Record: 154 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=bethel
# api call successful
# Processing Record: 155 | scottsburgh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=scottsburgh
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 156 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=barrow
# api call successful
# Processing Record: 157 | gravdal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=gravdal
# api call successful
# Processing Record: 158 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=mayo
# api call successful
# Processing Record: 159 | anlu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=anlu
# api call successful
# Processing Record: 160 | norden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=norden
# api call successful
# Processing Record: 161 | tasbuget
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=tasbuget
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 162 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=los llanos de aridane
# api call successful
# Processing Record: 163 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=saldanha
# api call successful
# Processing Record: 164 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=longyearbyen
# api call successful
# Processing Record: 165 | poronaysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=poronaysk
# api call successful
# Processing Record: 166 | svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=svetlogorsk
# api call successful
# Processing Record: 167 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=amderma
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 168 | ellenabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ellenabad
# api call successful
# Processing Record: 169 | lalmohan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=lalmohan
# api call successful
# Processing Record: 170 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=qaqortoq
# api call successful
# Processing Record: 171 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=dunedin
# api call successful
# Processing Record: 172 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=kruisfontein
# api call successful
# Processing Record: 173 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=lagoa
# api call successful
# Processing Record: 174 | esmeralda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=esmeralda
# api call successful
# Processing Record: 175 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ixtapa
# api call successful
# Processing Record: 176 | raga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=raga
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 177 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=arraial do cabo
# api call successful
# Processing Record: 178 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=belushya guba
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 179 | trinidad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=trinidad
# api call successful
# Processing Record: 180 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=new norfolk
# api call successful
# Processing Record: 181 | manavalakurichi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=manavalakurichi
# api call successful
# Processing Record: 182 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=havoysund
# api call successful
# Processing Record: 183 | bakchar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=bakchar
# api call successful
# Processing Record: 184 | lubango
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=lubango
# api call successful
# Processing Record: 185 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=palmer
# api call successful
# Processing Record: 186 | salym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=salym
# api call successful
# Processing Record: 187 | rungata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=rungata
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 188 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=te anau
# api call successful
# Processing Record: 189 | rodrigues alves
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=rodrigues alves
# api call successful
# Processing Record: 190 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=esperance
# api call successful
# Processing Record: 191 | abrau-dyurso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=abrau-dyurso
# api call successful
# Processing Record: 192 | rio grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=rio grande
# api call successful
# Processing Record: 193 | moose factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=moose factory
# api call successful
# Processing Record: 194 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=beloha
# api call successful
# Processing Record: 195 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=provideniya
# api call successful
# Processing Record: 196 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=port elizabeth
# api call successful
# Processing Record: 197 | hit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=hit
# api call successful
# Processing Record: 198 | aracati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=aracati
# api call successful
# Processing Record: 199 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ponta do sol
# api call successful
# Processing Record: 200 | ngukurr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ngukurr
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 201 | carballo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=carballo
# api call successful
# Processing Record: 202 | astara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=astara
# api call successful
# Processing Record: 203 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=cabo san lucas
# api call successful
# Processing Record: 204 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=poum
# api call successful
# Processing Record: 205 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=victoria
# api call successful
# Processing Record: 206 | waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=waingapu
# api call successful
# Processing Record: 207 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=samusu
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 208 | aflu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=aflu
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 209 | champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=champerico
# api call successful
# Processing Record: 210 | kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=kutum
# api call successful
# Processing Record: 211 | high level
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=high level
# api call successful
# Processing Record: 212 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=yar-sale
# api call successful
# Processing Record: 213 | xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=xining
# api call successful
# Processing Record: 214 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=tumannyy
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 215 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=marcona
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 216 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=vila velha
# api call successful
# Processing Record: 217 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=porto novo
# api call successful
# Processing Record: 218 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=dingle
# api call successful
# Processing Record: 219 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=tiksi
# api call successful
# Processing Record: 220 | ostersund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ostersund
# api call successful
# Processing Record: 221 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=labuhan
# api call successful
# Processing Record: 222 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=tuktoyaktuk
# api call successful
# Processing Record: 223 | polson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=polson
# api call successful
# Processing Record: 224 | dubrovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=dubrovka
# api call successful
# Processing Record: 225 | kargasok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=kargasok
# api call successful
# Processing Record: 226 | oranjestad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=oranjestad
# api call successful
# Processing Record: 227 | yabelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=yabelo
# api call successful
# Processing Record: 228 | lagos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=lagos
# api call successful
# Processing Record: 229 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ambilobe
# api call successful
# Processing Record: 230 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=chuy
# api call successful
# Processing Record: 231 | maarianhamina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=maarianhamina
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 232 | fairview
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=fairview
# api call successful
# Processing Record: 233 | urdzhar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=urdzhar
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 234 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=richards bay
# api call successful
# Processing Record: 235 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=cayenne
# api call successful
# Processing Record: 236 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=maceio
# api call successful
# Processing Record: 237 | podporozhye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=podporozhye
# api call successful
# Processing Record: 238 | novikovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=novikovo
# api call successful
# Processing Record: 239 | toliary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=toliary
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 240 | saskatoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=saskatoon
# api call successful
# Processing Record: 241 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=maniitsoq
# api call successful
# Processing Record: 242 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=thompson
# api call successful
# Processing Record: 243 | cascais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=cascais
# api call successful
# Processing Record: 244 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=saint george
# api call successful
# Processing Record: 245 | mizan teferi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=mizan teferi
# api call successful
# Processing Record: 246 | marsa matruh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=marsa matruh
# api call successful
# Processing Record: 247 | akyab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=akyab
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 248 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=praia da vitoria
# api call successful
# Processing Record: 249 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=hobyo
# api call successful
# Processing Record: 250 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=east london
# api call successful
# Processing Record: 251 | korem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=korem
# api call successful
# Processing Record: 252 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=torbay
# api call successful
# Processing Record: 253 | itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=itoman
# api call successful
# Processing Record: 254 | denpasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=denpasar
# api call successful
# Processing Record: 255 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=norman wells
# api call successful
# Processing Record: 256 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=mogadishu
# api call successful
# Processing Record: 257 | babanusah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=babanusah
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 258 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=tasiilaq
# api call successful
# Processing Record: 259 | stromness
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=stromness
# api call successful
# Processing Record: 260 | marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=marzuq
# api call successful
# Processing Record: 261 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=grindavik
# api call successful
# Processing Record: 262 | kerki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=kerki
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 263 | pemba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=pemba
# api call successful
# Processing Record: 264 | hay river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=hay river
# api call successful
# Processing Record: 265 | atasu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=atasu
# api call successful
# Processing Record: 266 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=turukhansk
# api call successful
# Processing Record: 267 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=lompoc
# api call successful
# Processing Record: 268 | khorinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=khorinsk
# api call successful
# Processing Record: 269 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=airai
# api call successful
# Processing Record: 270 | hurghada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=hurghada
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 271 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=vardo
# api call successful
# Processing Record: 272 | nguiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=nguiu
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 273 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=taoudenni
# api call successful
# Processing Record: 274 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ancud
# api call successful
# Processing Record: 275 | fevralsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=fevralsk
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 276 | fort saint john
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=fort saint john
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 277 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=mount isa
# ...
# api call successful
# Processing Record: 541 | nsanje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=nsanje
# api call successful
# Processing Record: 542 | baghdad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=baghdad
# api call successful
# Processing Record: 543 | samana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=samana
# api call successful
# Processing Record: 544 | bonnyville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=bonnyville
# api call successful
# Processing Record: 545 | lulea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=lulea
# api call successful
# Processing Record: 546 | verkhoturye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=verkhoturye
# api call successful
# Processing Record: 547 | oum hadjer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=oum hadjer
# api call successful
# Processing Record: 548 | jose de freitas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=jose de freitas
# api call successful
# Processing Record: 549 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=hualmay
# api call successful
# Processing Record: 550 | hermiston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=hermiston
# api call successful
# Processing Record: 551 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=bubaque
# api call successful
# Processing Record: 552 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=komsomolskiy
# api call successful
# Processing Record: 553 | bolungarvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=bolungarvik
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 554 | loikaw
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=loikaw
# api call successful
# Processing Record: 555 | vega de alatorre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=vega de alatorre
# api call successful
# Processing Record: 556 | yarada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=yarada
# api call successful
# Processing Record: 557 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ahipara
# api call successful
# Processing Record: 558 | xudat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=xudat
# api call successful
# Processing Record: 559 | avenal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=avenal
# api call successful
# Processing Record: 560 | olutanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=olutanga
# api call successful
# Processing Record: 561 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=alta floresta
# api call successful
# Processing Record: 562 | belaya gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=belaya gora
# api call successful
# Processing Record: 563 | okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=okha
# api call successful
# Processing Record: 564 | lethem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=lethem
# api call successful
# Processing Record: 565 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=hofn
# api call successful
# Processing Record: 566 | gorkovskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=gorkovskoye
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 567 | porosozero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=porosozero
# api call successful
# Processing Record: 568 | luau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=luau
# api call successful
# Processing Record: 569 | cagayan de tawi-tawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=cagayan de tawi-tawi
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 570 | miri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=miri
# api call successful
# Processing Record: 571 | iki-burul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=iki-burul
# api call successful
# Processing Record: 572 | puerto penasco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=puerto penasco
# api call successful
# Processing Record: 573 | goure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=goure
# api call successful
# Processing Record: 574 | bonoua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=bonoua
# api call successful
# Processing Record: 575 | ramapuram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ramapuram
# api call successful
# Processing Record: 576 | sidi ali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=sidi ali
# api call successful
# Processing Record: 577 | port-cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=port-cartier
# api call successful
# Processing Record: 578 | moussoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=moussoro
# api call successful
# Processing Record: 579 | ksenyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ksenyevka
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 580 | zhoucheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=zhoucheng
# api call successful
# Processing Record: 581 | elmira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=elmira
# api call successful
# Processing Record: 582 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=lata
# api call successful
# Processing Record: 583 | bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=bilma
# api call successful
# Processing Record: 584 | zakamensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=zakamensk
# api call successful
# Processing Record: 585 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=sorland
# api call successful
# Processing Record: 586 | brownsville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=brownsville
# api call successful
# Processing Record: 587 | herat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=herat
# api call successful
# Processing Record: 588 | uptar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=uptar
# api call successful
# Processing Record: 589 | arzgir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=arzgir
# api call successful
# Processing Record: 590 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=bandarbeyla
# api call successful
# Processing Record: 591 | dudinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=dudinka
# api call successful
# Processing Record: 592 | shu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=shu
# api call successful
# Processing Record: 593 | mudgee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=mudgee
# api call successful
# Processing Record: 594 | hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=hirara
# api call successful
# Processing Record: 595 | parrita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=parrita
# api call successful
# Processing Record: 596 | tupelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=tupelo
# api call successful
# Processing Record: 597 | arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=arlit
# api call successful
# Processing Record: 598 | zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=zhangjiakou
# api call successful
# Processing Record: 599 | rosarito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=rosarito
# api call successful
# Processing Record: 600 | grants pass
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=grants pass
# api call successful
# Processing Record: 601 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=oranjemund
# api call successful
# Processing Record: 602 | pitimbu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=pitimbu
# api call successful
# Processing Record: 603 | yomitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=yomitan
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 604 | jijiga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=jijiga
# api call successful
# Processing Record: 605 | murray bridge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=murray bridge
# api call successful
# Processing Record: 606 | matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=matara
# api call successful
# Processing Record: 607 | brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=brae
# api call successful
# Processing Record: 608 | pringsewu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=pringsewu
# api call successful
# Processing Record: 609 | libertador general san martin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=libertador general san martin
# api call successful
# Processing Record: 610 | mattru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=mattru
# api call successful
# Processing Record: 611 | rostovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=rostovka
# api call successful
# Processing Record: 612 | weatherford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=weatherford
# api call successful
# Processing Record: 613 | santa cruz do capibaribe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=santa cruz do capibaribe
# api call successful
# Processing Record: 614 | chivilcoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=chivilcoy
# api call successful
# Processing Record: 615 | ewing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ewing
# api call successful
# Processing Record: 616 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=naze
# api call successful
# Processing Record: 617 | gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=gizo
# api call successful
# Processing Record: 618 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=mehamn
# api call successful
# Processing Record: 619 | karaul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=karaul
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 620 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=souillac
# api call successful
# Processing Record: 621 | erzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=erzin
# api call successful
# Processing Record: 622 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ugoofaaru
# api call successful
# Processing Record: 623 | imbituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=imbituba
# api call successful
# Processing Record: 624 | phangnga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=phangnga
# api call successful
# Processing Record: 625 | tambovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=tambovka
# api call successful
# Processing Record: 626 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=sioux lookout
# api call successful
# Processing Record: 627 | cassilandia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=cassilandia
# api call successful
# Processing Record: 628 | kryvyy rih
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=kryvyy rih
# api call successful
# Processing Record: 629 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=cap malheureux
# api call successful
# Processing Record: 630 | sundvollen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=sundvollen
# api call failed
# Response code: 404Response Message: city not found
# Processing Record: 631 | ahuimanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=ahuimanu
# api call successful
# Processing Record: 632 | allanridge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=allanridge
# api call successful
# Processing Record: 633 | fort morgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d644e1dac86227a5e3f63a0ae8309fc6&q=fort morgan
# api call successful
# -------------------------------
# End Data Retreival
# -------------------------------

# %%
fig, ax = plt.subplots()
ax.scatter(lat,temp,alpha=0.75,marker="o",s=60,edgecolors = 'black',color = 'blue' , label = 'Cities')
# Incorporate the other graph properties
ax.set_xlabel('Latitude')
ax.set_ylabel('Max Temperature (F)')
ax.set_title('City Latitude vs Max Temperature ( ' + date + ' )')
ax.grid(True,color='w')
ax.set_facecolor('lightgrey')
# Save Figure
plt.savefig("City Latitude vs Max Temperature.png")

plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(lat,humidity,alpha=0.75,marker="o",edgecolors = 'black',color = 'blue' , label = 'Cities')
# Incorporate the other graph properties
ax.set_xlabel('Latitude')
ax.set_ylabel('Humidity (%)')
ax.set_title('City Latitude vs Humidity ( ' + date + ' )')
ax.grid(True,color='w')
ax.set_facecolor('lightgrey')
# Save Figure
plt.savefig("City Latitude vs Humidity.png")
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(lat,windspeed,alpha=0.75,marker="o",edgecolors = 'black',color = 'blue' , label = 'Cities')
# Incorporate the other graph properties
ax.set_xlabel('Latitude')
ax.set_ylabel('Wind Speed ( mph )')
ax.set_title('Latitude vs Wind Speed ( ' + date + ' )' )
ax.grid(True,color='w')
ax.set_facecolor('lightgrey')
# Save Figure
plt.savefig("Latitude vs Wind Speed.png")

plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(lat,cloudiness,alpha=0.75,marker="o",edgecolors = 'black',color = 'blue' , label = 'Cities')
# Incorporate the other graph properties
ax.set_xlabel('Latitude')
ax.set_ylabel('Cloudiness ( % ) ')
ax.set_title('Latitude vs Cloudiness ( ' + date + ' )')
ax.grid(True,color='w')
ax.set_facecolor('lightgrey')
# Save Figure
plt.savefig("Latitude vs Cloudiness.png")

plt.show()

# %%
weatherinfo = {'City ID' : foundcityID, 'City': foundcity, 'Country': cc
               'Latitude': lat , 'Longitude' : lon,
               'Max Temperature': temp, 'Humidity' : humidity, 
               'Cloudiness' : cloudiness, 'Wind Speed' : windspeed,
                'Date' : dt}

df = pd.DataFrame.from_dict(weatherinfo)
df.head()
# Out:
#            City  City ID  Cloudiness           Date  Humidity  Latitude  \
# 0         vaini  1273574          92  July 23, 2018        98     15.34
# 1          vila  3164565          40  July 23, 2018        69     45.18
# 2         tabas   113659           0  July 23, 2018        17     33.60
# 3         kapaa  5848280          90  July 23, 2018        83     22.08
# 4  punta arenas  3874787           0  July 23, 2018        84    -53.16
#
#    Longitude  Temperature  Wind Speed
# 0      74.49        72.89        7.65
# 1       8.40        73.40        6.93
# 2      56.92        99.80        7.09
# 3    -159.32        80.60       12.75
# 4     -70.91        39.20       13.87

# %%
df.to_csv(output_data_file,sep=',',index = False)
